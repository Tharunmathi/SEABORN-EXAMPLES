# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\tharun\downloads\fda\myenv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\THARUN\\OneDrive\\Desktop\\Mark Sheet.csv")
data=pd.DataFrame(df)
print(data)

sb.distplot(data['Maths']) #distplot=histogram+curved line
plt.show()
# Out:
#    Name_of_student  Roll_number  Telugu  English  Maths  Science  social
# 0           Tharun          101      98       75     67       94      63
# 1          Chandan          102      66       93     79       55      62
# 2             Uday          103      56       99     76       79      94
# 3      Balavardhan          104      79       92     44       58      95
# 4           Ramesh          105      95       83     50       59      84
# 5           Suresh          106      93       77     39       39      72
# 6         Mallaiah          107      87       49     68       99      53
# 7          Hemanth          108      77       58     94       88      61
# 8            Pavan          109      48       55     68       67      91
# 9       Sudharshan          110      30       59     68       58      71
# 10          Mekala          111      58       93     30       40      66
# 11          Sarath          112      49       88     49       39      49
# ...

# %%
data=sb.load_dataset('diamonds')
print(data)

sb.distplot(data['carat'],bins=10)  #distplot=histogram+curved line with bins
plt.show()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
# ...

# %%
data=sb.load_dataset('dots')
print(data)

sb.distplot(data['coherence']) #distplot=histogram+curved line
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data1=sb.load_dataset('dots')
print(data1)

sb.jointplot(x='time',y='coherence',data=data1) #joint plot is to compare x and y (both numeric comparision)
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
df=pd.read_csv("C:\\Users\\THARUN\\OneDrive\\Desktop\\Mark Sheet.csv")
data=pd.DataFrame(df)
print(data)

sb.jointplot(x='English',y='Maths',data=data) #jointplot= compare x and y (numeric comparision)
plt.show()
# Out:
#    Name_of_student  Roll_number  Telugu  English  Maths  Science  social
# 0           Tharun          101      98       75     67       94      63
# 1          Chandan          102      66       93     79       55      62
# 2             Uday          103      56       99     76       79      94
# 3      Balavardhan          104      79       92     44       58      95
# 4           Ramesh          105      95       83     50       59      84
# 5           Suresh          106      93       77     39       39      72
# 6         Mallaiah          107      87       49     68       99      53
# 7          Hemanth          108      77       58     94       88      61
# 8            Pavan          109      48       55     68       67      91
# 9       Sudharshan          110      30       59     68       58      71
# 10          Mekala          111      58       93     30       40      66
# 11          Sarath          112      49       88     49       39      49
# ...

# %%
data1=sb.load_dataset('iris')
print(data1)

sb.catplot(x='species',y='sepal_length',data=data1) #cat plot is to compare x and y (one numeric and one theory comparision)
sb.catplot(x='species',y='sepal_length',data=data1,kind= 'box')
sb.catplot(x='species',y='sepal_length',data=data1,kind='violin')

plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data1=sb.load_dataset('dots')
print(data1)
graph=sb.FacetGrid(data1,col="align",hue="choice") # facet grid is to compare theoritical columns
graph.map(plt.scatter,'align','choice')
plt.grid(axis='y')
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sb.lmplot(x="English", y="Maths", data=data)        # lm plot
plt.show()

# %%
sb.swarmplot(x="Maths", y="English", data=data)
plt.show()

# %%
sb.pairplot(data)
plt.show()

# %%
sales = pd.read_excel("C:\\Users\\THARUN\\Downloads\\DATASETS\\sales.xlsx")
sales
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %% [markdown]
# # Scatter plot

# %%
sns.relplot("Sales","Profit",data = sales)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,hue = "Order Priority") # based on order priority hue =  color code
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,hue = "Order Priority",style = "Order Priority") # different style options
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,hue = "Order Priority",style = "Ship Mode")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,size = "Discount")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,size = "Discount",sizes = (25,200))
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # line plot

# %%
sns.relplot("Order Date","Sales",data = sales,kind = "line")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sales["Year"] = sales["Order Date"].dt.year

# %%
sales.Year.unique()
# Out:
# array([2010, 2012, 2011, 2009], dtype=int64)

# %%
sns.relplot("Year","Sales",data = sales,kind = "line")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",estimator = None)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",estimator = sum)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode",style = "Product Category")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode",style = "Product Category",ci = None)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode",col = "Product Category",ci = None)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode",col = "Region",ci = None)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Year","Sales",data = sales,kind = "line",hue = "Ship Mode",col = "Region",col_wrap = 4,ci = None)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Facet to show multiple chart

# %%
sns.relplot("Sales","Profit",data = sales,col ="Customer Segment")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,col ="Customer Segment",col_wrap = 2)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,col ="Customer Segment",col_wrap = 2,hue = "Order Priority")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,col ="Customer Segment",col_wrap = 2,hue = "Ship Mode")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot("Sales","Profit",data = sales,col ="Customer Segment",row = "Product Category",hue = "Order Priority")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # swarm plot

# %%
sns.catplot("Ship Mode","Sales",data = sales)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Ship Mode","Sales",data = sales,hue = "Customer Segment")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Ship Mode","Sales",data = sales,jitter = False)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Ship Mode","Sales",data = sales.query("Profit > 1000"),jitter =False)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Ship Mode","Sales",data = sales.query("Profit > 1000"),kind = "swarm")
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Box plot

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",data = sales,kind = "box")

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",hue  ="Ship Mode",data = sales,kind = "box")

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",hue  ="Ship Mode",hue_order=["Delivery Truck","Regular Air","Express Air"],data = sales,kind = "box")

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",row ="Ship Mode",data = sales,kind = "box")

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",col ="Ship Mode",data = sales,kind = "box")

# %%
sns.catplot(x="Product Category",y = "Shipping Cost",row = "Customer Segment",col ="Ship Mode",data = sales,kind = "box")

# %% [markdown]
# # violin chart

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.catplot(x = "Product Category",y = "Shipping Cost",data = sales,kind = "violin")

# %%
sns.catplot(x = "Product Category",y = "Shipping Cost",hue = "Ship Mode",data = sales,kind = "violin")

# %%
sns.catplot(x = "Product Category",y = "Shipping Cost",hue = "Ship Mode",inner = "stick",data = sales,kind = "violin")

# %% [markdown]
# # Bar Chart

# %%
sns.catplot(x = "Product Category",y = "Sales",data = sales,kind = "bar")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",data = sales,kind = "bar")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",row = "Customer Segment",data = sales,kind = "bar")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",col = "Customer Segment",data = sales,kind = "bar")

# %%
sns.catplot(y = "Product Category",x = "Sales",data = sales,kind = "bar")

# %% [markdown]
# # Point plot

# %%
sns.catplot(x = "Product Category",y = "Sales",data = sales,kind = "point")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",data = sales,kind = "point")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Region",data = sales,kind = "point")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",row = "Customer Segment",data = sales,kind = "point")

# %%
sns.catplot(x = "Product Category",y = "Sales",hue = "Ship Mode",col = "Customer Segment",data = sales,kind = "point")

# %% [markdown]
# # Distribution plot

# %%
sns.distplot(sales["Sales"])
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(sales["Profit"])
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(sales["Profit"],kde = False)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit'>

# %%
sns.distplot(sales["Profit"],hist = False)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(sales["Profit"],hist = False,rug = True)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(sales["Profit"],rug = True,bins = 13)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.kdeplot(sales.Profit,bw =100)
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 100 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>
